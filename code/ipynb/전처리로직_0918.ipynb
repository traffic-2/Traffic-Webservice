# %% [markdown]
# # 전처리로직

# %%
import pandas as pd

# %%
df = pd.read_csv('교통량데이터프레임(날씨추가전).csv',encoding='utf-8')
df_2 = pd.read_csv('종로구_날씨데이터(수정).csv',encoding='cp949')

# %%
df.head()

# %%
df.info()

# %%
df_2.head()

# %%
df_2.info()

# %% [markdown]
# ## 이 부분은 안봐도 됌

# %%
# df['기준']=df['년도']+df['월']+df['일']+df['시간']

# %%
# df.head()

# %%
# df.info()

# %% [markdown]
# ## 병합 기준

# %%
df[['년도','월','일','시간']]=df[['년도','월','일','시간']].astype(str)

# %%
df['기준2'] = df['년도']+'-'+df['월']+'-'+df['일']+'-'+df['시간']

# %%
df.head()
# Out:
#      년도  월  일 요일 시간        교통량측정지점명 사고다발지점     교통량         기준2
# 0  2017  1  1  일  0  대학로(한국방송통신대학교)  이화사거리  1021.0  2017-1-1-0
# 1  2017  1  1  일  1  대학로(한국방송통신대학교)  이화사거리   778.0  2017-1-1-1
# 2  2017  1  1  일  2  대학로(한국방송통신대학교)  이화사거리   601.0  2017-1-1-2
# 3  2017  1  1  일  3  대학로(한국방송통신대학교)  이화사거리   512.0  2017-1-1-3
# 4  2017  1  1  일  4  대학로(한국방송통신대학교)  이화사거리   534.0  2017-1-1-4

# %%
df['기준2']
# Out:
# 0            2017-1-1-0
# 1            2017-1-1-1
# 2            2017-1-1-2
# 3            2017-1-1-3
# 4            2017-1-1-4
#               ...
# 131395    2019-12-31-19
# 131396    2019-12-31-20
# 131397    2019-12-31-21
# 131398    2019-12-31-22
# 131399    2019-12-31-23
# Name: 기준2, Length: 131400, dtype: object

# %% [markdown]
# ## 병합되면 몇 행일지 조사

# %%
df.shape

# %%
df_2.shape

# %%
df_2.head()
# Out:
#    Unnamed: 0   지점                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  \
# 0           0  108  2017-01-01 00:00     0.2      NaN      2.2      20.0
# 1           1  108  2017-01-01 01:00     0.0      NaN      1.4      20.0
# 2           2  108  2017-01-01 02:00    -0.3      NaN      1.9      50.0
# 3           3  108  2017-01-01 03:00    -0.7      NaN      2.0      50.0
# 4           4  108  2017-01-01 04:00    -1.1      NaN      1.6      20.0
#
#    습도(%)  증기압(hPa)  이슬점온도(°C)  ...  운형(운형약어)  최저운고(100m )  시정(10m)  \
# 0   79.0       4.9       -3.0  ...        Sc          8.0      491
# 1   78.0       4.8       -3.3  ...       NaN          7.0      549
# 2   81.0       4.9       -3.1  ...       NaN          8.0      483
# 3   84.0       4.9       -3.0  ...       NaN          NaN      436
# 4   85.0       4.8       -3.3  ...       NaN          NaN      430
#
#    지면상태(지면상태코드)  현상번호(국내식)  지면온도(°C)  5cm 지중온도(°C)  10cm 지중온도(°C)  \
# ...

# %% [markdown]
# ## 일시를 슬라이싱해서 칼럼으로 추가

# %%
df_2['년도']=df_2['일시'].str[:4]

# %%
df_2['월']= df_2['일시'].str[5:7]

# %%
# df_2['시간'].astype(int)

# %%
df_2['일'] = df_2['일시'].str[8:10]

# %%
df_2[['월','일']]=df_2[['월','일']].astype(str)

# %%
df_2['시간']=df_2['일시'].str[-5:-3]

# %%
df_2['기준2']=df_2['기준2'].astype(str)

# %%
df_2['기준2'].replace(' ','')

# %%
df_2['기준2'].astype(int)

# %%
df_2['시간']=df_2['시간'].astype(int)

# %%
df_2['시간']=df_2['시간'].astype(int)

# %%
df_2['시간']=df_2['시간'].astype(str)

# %%
df_2['기준2'] = df_2['년도']+'-'+df_2['월']+'-'+df_2['일']+'-'+df_2['시간']

# %%
df_2.head()
# Out:
#    Unnamed: 0   지점                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  \
# 0           0  108  2017-01-01 00:00     0.2      NaN      2.2      20.0
# 1           1  108  2017-01-01 01:00     0.0      NaN      1.4      20.0
# 2           2  108  2017-01-01 02:00    -0.3      NaN      1.9      50.0
# 3           3  108  2017-01-01 03:00    -0.7      NaN      2.0      50.0
# 4           4  108  2017-01-01 04:00    -1.1      NaN      1.6      20.0
#
#    습도(%)  증기압(hPa)  이슬점온도(°C)  ...  5cm 지중온도(°C)  10cm 지중온도(°C)  \
# 0   79.0       4.9       -3.0  ...           0.1            0.3
# 1   78.0       4.8       -3.3  ...           0.0            0.3
# 2   81.0       4.9       -3.1  ...           0.0            0.3
# 3   84.0       4.9       -3.0  ...           0.0            0.3
# 4   85.0       4.8       -3.3  ...          -0.1            0.4
#
#    20cm 지중온도(°C)  30cm 지중온도(°C)    년도  월  일  시간          기준         기준2
# ...

# %%
df['기준2']
# Out:
# 0            2017-1-1-0
# 1            2017-1-1-1
# 2            2017-1-1-2
# 3            2017-1-1-3
# 4            2017-1-1-4
#               ...
# 131395    2019-12-31-19
# 131396    2019-12-31-20
# 131397    2019-12-31-21
# 131398    2019-12-31-22
# 131399    2019-12-31-23
# Name: 기준2, Length: 131400, dtype: object

# %%
df_2['기준2']
# Out:
# 0           2017-1-1-0
# 1           2017-1-1-1
# 2           2017-1-1-2
# 3           2017-1-1-3
# 4           2017-1-1-4
#              ...
# 26275    2019-12-31-19
# 26276    2019-12-31-20
# 26277    2019-12-31-21
# 26278    2019-12-31-22
# 26279    2019-12-31-23
# Name: 기준2, Length: 26280, dtype: object

# %%
df_2[['년도','월','일','시간']]=df_2[['년도','월','일','시간']].astype(str)

# %%
# pd.merge(df, df_2, on='년도','월','일','시간', how="inner")

# %%
df_2['기준2']=df_2['기준2'].replace(' ','')

# %% [markdown]
# ## 공백이 실수를 그대로 str 형태로 바꿔서 그런거라 생각하고 ,
# ## int형으로 변환하고 str형태로 다시 칼럼추가

# %%
df_2['시간'].astype(int)

# %% [markdown]
# ## 공백 제거 코드가 먹지 않음.

# %%
df_2['기준2'].str.strip()

# %%
df_2['기준']=df_2['년도']+df_2['월']+df_2['일']+df_2['시간']

# %%
# Out:
#        Unnamed: 0   지점                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  \
# 0               0  108  2017-01-01 00:00     0.2      NaN      2.2      20.0
# 1               1  108  2017-01-01 01:00     0.0      NaN      1.4      20.0
# 2               2  108  2017-01-01 02:00    -0.3      NaN      1.9      50.0
# 3               3  108  2017-01-01 03:00    -0.7      NaN      2.0      50.0
# 4               4  108  2017-01-01 04:00    -1.1      NaN      1.6      20.0
# ...           ...  ...               ...     ...      ...      ...       ...
# 26275        8755  108  2019-12-31 19:00    -6.9      NaN      1.7     290.0
# 26276        8756  108  2019-12-31 20:00    -7.0      NaN      2.9     290.0
# 26277        8757  108  2019-12-31 21:00    -7.4      NaN      0.8      20.0
# 26278        8758  108  2019-12-31 22:00    -8.2      NaN      0.0       0.0
# 26279        8759  108  2019-12-31 23:00    -7.4      NaN      0.0       0.0
#
# ...

# %%
df_a=pd.merge(df, df_2, on='기준2', how="inner")

# %%
dfdf_=df_a.sort_values(by=['년도_x','월_x','일_x','사고다발지점','시간_x',], axis=0)

# %%
df_a.shape
# Out:
# (131400, 42)

# %%
df_a.shape

# %%
# df______.to_csv('0915.csv',encoding='cp949')

# %%
# df______.shape

# %%
# df______.tail()

# %% [markdown]
# ## 확인

# %%
df.head()

# %%
df_2.head()

# %%
# df_a.to_csv('교통량+날씨.csv',encoding='cp949')

# %% [markdown]
# ## 저장

# %%
df =pd.read_csv('교통량+날씨.csv',encoding='cp949')

# %% [markdown]
# ## 칼럼순으로 정리

# %%
dfdf_=dfdf.sort_values(by=['년도_x','년도_x','월_x','일_x','사고다발지점'], axis=0)

# %%
dfdf_.head(30)
# Out:
#     년도_x  월_x  일_x 요일  시간_x    교통량측정지점명     사고다발지점     교통량                일시  \
# 0   2017    1    1  일     0  세종대로(시청역2)  광하문우체국사거리  1021.0   2017-01-01 0:00
# 1   2017    1    1  일     1  세종대로(시청역2)  광하문우체국사거리   778.0   2017-01-01 1:00
# 2   2017    1    1  일     2  세종대로(시청역2)  광하문우체국사거리   601.0   2017-01-01 2:00
# 3   2017    1    1  일     3  세종대로(시청역2)  광하문우체국사거리   512.0   2017-01-01 3:00
# 4   2017    1    1  일     4  세종대로(시청역2)  광하문우체국사거리   534.0   2017-01-01 4:00
# 5   2017    1    1  일     5  세종대로(시청역2)  광하문우체국사거리   825.0   2017-01-01 5:00
# 6   2017    1    1  일     6  세종대로(시청역2)  광하문우체국사거리  1415.0   2017-01-01 6:00
# 7   2017    1    1  일     7  세종대로(시청역2)  광하문우체국사거리  1870.0   2017-01-01 7:00
# 8   2017    1    1  일     8  세종대로(시청역2)  광하문우체국사거리  2085.0   2017-01-01 8:00
# 9   2017    1    1  일     9  세종대로(시청역2)  광하문우체국사거리  2124.0   2017-01-01 9:00
# 10  2017    1    1  일    10  세종대로(시청역2)  광하문우체국사거리  2148.0  2017-01-01 10:00
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
dfdf_.head(30)
# Out:
#      년도_x  월_x  일_x 요일  시간_x        교통량측정지점명     사고다발지점     교통량  \
# 0    2017    1    1  일     0      세종대로(시청역2)  광하문우체국사거리  1021.0
# 24   2017    1    1  일     0        종로(동묘앞역)    동묘앞역사거리  1021.0
# 48   2017    1    1  일     0        율곡로(안국역)     안국역사거리  1021.0
# 72   2017    1    1  일     0  대학로(한국방송통신대학교)      이화사거리  1021.0
# 96   2017    1    1  일     0       종로(종로3가역)   종로3가역사거리   796.0
# 1    2017    1    1  일     1      세종대로(시청역2)  광하문우체국사거리   778.0
# 25   2017    1    1  일     1        종로(동묘앞역)    동묘앞역사거리   778.0
# 49   2017    1    1  일     1        율곡로(안국역)     안국역사거리   778.0
# 73   2017    1    1  일     1  대학로(한국방송통신대학교)      이화사거리   778.0
# 97   2017    1    1  일     1       종로(종로3가역)   종로3가역사거리   857.0
# 2    2017    1    1  일     2      세종대로(시청역2)  광하문우체국사거리   601.0
# 26   2017    1    1  일     2        종로(동묘앞역)    동묘앞역사거리   601.0
# 50   2017    1    1  일     2        율곡로(안국역)     안국역사거리   601.0
# 74   2017    1    1  일     2  대학로(한국방송통신대학교)      이화사거리   601.0
# ...

# %% [markdown]
# ## 저장2

# %%
dfdf_.shape
# Out:
# (131400, 42)

# %%
dfdf_.to_csv('교통량+날씨_0928.csv',encoding='cp949')
