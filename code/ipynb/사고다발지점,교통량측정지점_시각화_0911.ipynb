# %% [markdown]
# # 교통 관측지점 데이터와 교통다발지점 데이터 시각화

# %%
import pandas as pd

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 3C26-45E0
#
#  C:\Users\cityo\Desktop\Git_Space\jupyter\교통 디렉터리
#
# 2021-09-13  오전 08:48    <DIR>          .
# 2021-09-13  오전 08:48    <DIR>          ..
# 2021-09-13  오전 08:40    <DIR>          .ipynb_checkpoints
# 2021-09-09  오후 07:59            50,355 0909.ipynb
# 2021-09-11  오후 07:10             6,496 0911.ipynb
# 2021-09-07  오후 04:38             8,045 1.csv
# 2021-09-11  오후 04:14            25,769 19년.csv
# 2021-09-07  오후 04:38            10,712 2.csv
# 2021-09-04  오후 07:03            21,714 20210701_01_데이터수집_selenium-checkpoint.ipynb
# 2021-09-04  오후 07:42             6,981 20210701_02_데이터수집_coffeebean(자바스크립트)-checkpoint.ipynb
# 2021-07-18  오전 02:50        11,177,472 chromedriver.exe
# 2021-09-07  오후 04:39            92,547 Untitled.ipynb
# 2021-09-13  오전 08:40    <DIR>          교통데이터
# 2021-09-08  오후 05:12           256,528 교통사고_강남구.csv
# 2021-09-08  오후 05:11           151,623 교통사고_강동구.csv
# 2021-09-08  오후 05:12           191,288 교통사고_강북구.csv
# 2021-09-09  오전 11:09           263,279 교통사고_송파구.csv
# 2021-09-09  오전 11:46           269,334 교통사고_영등포구.csv
# 2021-09-09  오후 02:42            25,353 셀리니움 실습 0905.ipynb
#               15개 파일          12,557,496 바이트
#                4개 디렉터리  208,029,720,576 바이트 남음

# %%
df = pd.read_csv('19년.csv',encoding='utf-8')

# %%
df_song = pd.read_csv('교통사고_강북구.csv',encoding='utf-8')
df_young = pd.read_csv('교통사고_강동구.csv',encoding='utf-8')

# %%
df_song=df_song[['위도','경도']]
df_young=df_young[['위도','경도']]

# %%
df_wido=df[['위도','경도']]

# %%
# df2=df[['위도','경도']]
# df2

# %%
df_wido=df_wido.dropna(subset=['위도'])

df_wido=df_wido.dropna(subset=['경도'])

# %% [markdown]
# # 강북구

# %%
# import folium
map=folium.Map(location=[df2['위도'].mean(),df2['경도'].mean()],zoom_start=12)


for n in df2.index:
#     name=df_route_p.loc[n,'_']
    
    location=[df2.loc[n,'위도'], df2.loc[n,'경도']]
#     adress=df_sample.loc[n,'구']
#     popup=f'{name}-{adress}'

    folium.Marker(
        location = location,
        icon=folium.Icon(color = 'green')
#         popup = popup,
    ).add_to(map)
# map



map2=folium.Map(location=[df_wido['위도'].mean(),df_wido['경도'].mean()],zoom_start=12)


for i in df_wido.index:
#     name=df_route_p.loc[n,'_']
    
    location2=[df_wido.loc[i,'위도'], df_wido.loc[i,'경도']]
#     adress=df_sample.loc[n,'구']
#     popup=f'{name}-{adress}'

    folium.Marker(
        location = location2,
        icon=folium.Icon(color = 'blue')
#         popup = popup,
    ).add_to(map)
map

# %% [markdown]
# # 강북구

# %%
import folium
map=folium.Map(location=[df_song['위도'].mean(),df_song['경도'].mean()],zoom_start=12)


for n in df_song.index:
#     name=df_route_p.loc[n,'_']
    
    location=[df_song.loc[n,'위도'], df_song.loc[n,'경도']]
#     adress=df_sample.loc[n,'구']
#     popup=f'{name}-{adress}'

    folium.Marker(
        location = location,
        icon=folium.Icon(color = 'green')
#         popup = popup,
    ).add_to(map)
# map



# map2=folium.Map(location=[df_song['위도'].mean(),df_song['경도'].mean()],zoom_start=12)


for i in df_wido.index:
#     name=df_route_p.loc[n,'_']
    
    location2=[df_wido.loc[i,'위도'], df_wido.loc[i,'경도']]
#     adress=df_sample.loc[n,'구']
#     popup=f'{name}-{adress}'

    folium.Marker(
        location = location2,
        icon=folium.Icon(color = 'blue')
#         popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e61d8ea3c8294eef996ff2add4f2ba9e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e61d8ea3c8294eef996ff2add4f2ba9e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e61d8ea3c8294eef996ff2add4f2ba9e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e61d8ea3c8294eef996ff2add4f2ba9e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.60017292535193%2C%20127.01993638066577%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# # 강동구

# %%
# import folium
map=folium.Map(location=[df_young['위도'].mean(),df_young['경도'].mean()],zoom_start=12)


for n in df_young.index:
#     name=df_route_p.loc[n,'_']
    
    location=[df_young.loc[n,'위도'], df_young.loc[n,'경도']]
#     adress=df_sample.loc[n,'구']
#     popup=f'{name}-{adress}'

    folium.Marker(
        location = location,
        icon=folium.Icon(color = 'green')
#         popup = popup,
    ).add_to(map)
# map



map2=folium.Map(location=[df_song['위도'].mean(),df_song['경도'].mean()],zoom_start=12)


for i in df_wido.index:
#     name=df_route_p.loc[n,'_']
    
    location2=[df_wido.loc[i,'위도'], df_wido.loc[i,'경도']]
#     adress=df_sample.loc[n,'구']
#     popup=f'{name}-{adress}'

    folium.Marker(
        location = location2,
        icon=folium.Icon(color = 'blue')
#         popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c5dec5484b474e4184c7098be44ea575%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c5dec5484b474e4184c7098be44ea575%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c5dec5484b474e4184c7098be44ea575%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c5dec5484b474e4184c7098be44ea575%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.467585448160335%2C%20127.13520702927912%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...
