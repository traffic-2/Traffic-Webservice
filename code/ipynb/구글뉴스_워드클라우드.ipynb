# %% [markdown]
# # 구글 뉴스 5번째 탭까지 크롤링

# %%
"""교통사고 부상자 돕다 숨진 이영곤… 동료들이 ‘의인 의사상’ 줬다 -
지난 1일 저녁 경남 진주시 대안동 이영곤 내과의원에 불이 켜졌다. 지난달 22일 원장 이씨가 고속도로 교통사고 부상자를 도우려다 사고로 숨진 뒤...
안전운전 불이행 때문에 ‘쾅’…교통사고 OECD 하위권
지난해 각종 교통사고 발생건수와 사망자가 전년보다 줄었지만 세계 주요국들과의 비교에선 여전히 하위권에 머문 것으로 나타났다. 또 도로 교통사고...
경기북부경찰청, 올 9월까지 교통사고 사망자 수 지난해 같은 기간보다 26.2% 감소
이륜차 교통사고 사망자는 41.4%(29명→17명) 줄었고 보행자 교통사고 사망자도 36.4%(55명→35명) 감소했다. 경찰은 이같은 감소 효과에 대해 정체 해소...
교통사고 후 112에 신고하자 아내에게 발차기를 27일 유튜브 한문철 TV에 고속도로에서 만취 운전자가 사고를 내더니 저와 제 아내를 폭행...
초등생, 크레인 피하다 교통사고…현장소장 “쇼하지마” 
제보자인 초등생 어머니 A씨에 따르면 사고는 충북 청주시 서원구에서 5월 3일 오후 3시경 발생했다. A씨는 “10세 딸아이가 하굣길에 교통사고가 났다.

대전 어린이 교통사고 전국 평균 상회

대전지역 어린이 인구 1000명당 교통사고 건수가 전국 평균 보다 많은 것으로 나타났다. 어린이 보호구역 100개소당 교통사고 건수도 전국 평균을...


[판결](단독) 유럽여행 현지서 도난 교통사고 연이어 발생했다면
.
유럽여행객들이 현지 인솔자들의 과실로 도난사고와 교통사고 피해를 잇따라 당해 여행사 대표가 거액의 배상책임을 지게 됐다.


[명형철 원장 건강칼럼] 추석연휴 교통량 증가에 교통사고 위험 ...
.
국토교통부는 추석을 맞아 9월 17일부터 6일간 정부합동 특별교통대책을 시행한다. 주요 교통법규 위반행위를 집중 단속하는 등 교통사고 사망자...
.
.
형사변호사, 음주운전 교통사고.. 엄벌 피하기 힘들어
.
특히 음주운전으로 인한 교통사고는 기본적인 처벌 수위가 높아 엄벌을 피하기 어렵기 때문에 당초 범죄에 연루되지 않도록 개개인이 노력해야 한다.

박완주, 스쿨존내 잘못된 교통시설물이 교통사고유발
.
현행 도로교통법 규정은 전국초등학교와 유치원, 어린이집 등의 등·하굣길 교통사고를 방지하고 통학생 안전 보호차원에서 약 16만 개소 어린이 보호구역."""""".

# %%
text = """매일경제 포항제철소 내 도로서 또 교통사고…1명 사망(종합).포스코 포항제철소 내에서 교통사고로 노동자가 숨지는 사고가 1년 새 2건 발생했다. 7일 포스코와 경찰 등에 따르면 이날 오전 10시 30분께 포항...\
한겨레포항제철소 내 도로서 또 교통사고…협력업체 노동자 1명 숨져포스코 포항제철소 안 도로에서 교통사고로 포스코 협력업체 계약직 노동자 1명이 숨졌다. 7일 포스코, 경찰, 고용노동부 등 설명을 종합하면,...\
연합뉴스포스코 포항제철소서 교통사고로 1명 사망(포항=연합뉴스) 손대성 기자 = 포스코 포항제철소 내에서 교통사고가 발생해 1명이 숨졌다. 7일 포스코와 경찰 등에 따르면 이날 오전 10시 30분께...\
이륜차 교통사고 사망자는 41.4%(29명→17명) 줄었고 보행자 교통사고 사망자도 36.4%(55명→35명) 감소했다. 경찰은 이같은 감소 효과에 대해 정체 해소...
교통사고 후 112에 신고하자 아내에게 발차기를 27일 유튜브 한문철 TV에 고속도로에서 만취 운전자가 사고를 내더니 저와 제 아내를 폭행...
초등생, 크레인 피하다 교통사고…현장소장 “쇼하지마” 
제보자인 초등생 어머니 A씨에 따르면 사고는 충북 청주시 서원구에서 5월 3일 오후 3시경 발생했다. A씨는 “10세 딸아이가 하굣길에 교통사고가 났다.

대전 어린이 교통사고 전국 평균 상회

대전지역 어린이 인구 1000명당 교통사고 건수가 전국 평균 보다 많은 것으로 나타났다. 어린이 보호구역 100개소당 교통사고 건수도 전국 평균을


[판결](단독) 유럽여행 현지서 도난 교통사고 연이어 발생했다면
.
유럽여행객들이 현지 인솔자들의 과실로 도난사고와 교통사고 피해를 잇따라 당해 여행사 대표가 거액의 배상책임을 지게 됐다.


[명형철 원장 건강칼럼] 추석연휴 교통량 증가에 교통사고 위험 ...
.
국토교통부는 추석을 맞아 9월 17일부터 6일간 정부합동 특별교통대책을 시행한다. 주요 교통법규 위반행위를 집중 단속하는 등 교통사고 사망자
.
.
형사변호사, 음주운전 교통사고.. 엄벌 피하기 힘들어
.
특히 음주운전으로 인한 교통사고는 기본적인 처벌 수위가 높아 엄벌을 피하기 어렵기 때문에 당초 범죄에 연루되지 않도록 개개인이 노력해야 한다.

박완주, 스쿨존내 잘못된 교통시설물이 교통사고유발
.
현행 도로교통법 규정은 전국초등학교와 유치원, 어린이집 등의 등·하굣길 교통사고를 방지하고 통학생 안전 보호차원에서 약 16만 개소 어린이 보호구역

"""

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# 한글 폰트 패스로 지정
import matplotlib.font_manager as fm
import re
import collections

# %%
spwords = set(STOPWORDS)  # 제외할 단어
spwords.add('교통사고가')
spwords.add('교통사고로')
spwords.add('교통사고를')
spwords.add('교통사고')
spwords.add('내')
spwords.add('사고로')
spwords.add('등')


# 제외하고 싶은 단어 추가

# %%
wc1 = WordCloud(max_font_size=200, stopwords=spwords, font_path='NanumSquareRoundB.ttf',
                background_color='white', width=800, height=800)
wc1.generate(text)

plt.figure(figsize=(10, 8))
plt.imshow(wc1)
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()
plt.savefig('hi2.jpg')
# [출처] [Python] Word cloud 간단예제|작성자 피노

# %%
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt
 
# wordcloud = WordCloud(font_path='C:\Users\cityo\anaconda3/Lib/site-packages/wordcloud/DroidSansMono', background_color='white').generate(text)

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show()

# %%
STOPWORDS='교통사고','포항제철소'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt 
 
    
stopwords = set(STOPWORDS) 
stopwords.add('') 
 
wordcloud = WordCloud(font_path='font/NanumGothic.ttf',stopwords=stopwords,background_color='white').generate(text)

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show()
